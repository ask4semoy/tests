# %% [markdown]
# <a href="https://colab.research.google.com/github/ask4semoy/tests/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/ask4semoy/tests/refs/heads/main/exercise_data.csv?token=GHSAT0AAAAAAC5JFVCJC4DQL7QAQ5VVOK7SZ4SPYPQ'
data = pd.read_csv(url)
data.head()
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  01-12-2020    110       130     409.1
# 1        60  02-12-2020    117       145     479.0
# 2        60  03-12-2020    103       135     340.0
# 3        45  04-12-2020    109       175     282.4
# 4        45  05-12-2020    117       148     406.0

# %%
#to read the last 5 rows
data.tail(10)
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 22        45          NaN    100       119     282.0
# 23        60   23-12-2020    130       101     300.0
# 24        45  24-12-2020'    105       132     246.0
# 25        60   25-12-2020    102       126     334.5
# 26        60   26-12-2020    100       120     250.0
# 27        60   27-12-2020     92       118     241.0
# 28        60   28-12-2020    103       132       NaN
# 29        60   29-12-2020    100       132     280.0
# 30        60   30-12-2020    102       129     380.3
# 31        60   31-12-2020     92       115     243.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
data.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %% [markdown]
# Missing Value Analysis

# %%
data.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %% [markdown]
# #to get the percentage of null values in each column (feature)

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# Duration    0.000
# Date        3.125
# Pulse       0.000
# Maxpulse    0.000
# Calories    6.250
# dtype: float64

# %%
data.shape
# Out:
# (32, 5)

# %%
#Renoving the pulse column
data = data.drop(['Pulse'], axis = 1)
data.head()
# Out:
#    Duration        Date  Maxpulse  Calories
# 0        60  01-12-2020       130     409.1
# 1        60  02-12-2020       145     479.0
# 2        60  03-12-2020       135     340.0
# 3        45  04-12-2020       175     282.4
# 4        45  05-12-2020       148     406.0

# %% [markdown]
# Data Reduction

# %% [markdown]
# Working with date & Time

# %%
from datetime import date
print(date.today())
print(datetime.now())
current_time = datetime.now()
print("Current Time:", current_time.strftime("%H:%M:%S"))
# Out:
# 2025-01-23
# 2025-01-23 10:51:11.713105
# Current Time: 10:51:11

# %% [markdown]
# Calculate difference between Pulse & MaxPulse and store in new column "DifferenceofPulse"

# %%
data['DifferenceofPulse'] = data['Maxpulse'] - data['Pulse']
data.head()
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories  DifferenceofPulse
# 0        60  01-12-2020    110       130     409.1                 20
# 1        60  02-12-2020    117       145     479.0                 28
# 2        60  03-12-2020    103       135     340.0                 32
# 3        45  04-12-2020    109       175     282.4                 66
# 4        45  05-12-2020    117       148     406.0                 31

# %% [markdown]
# Different Ways of Missing Values
#
#
# 1. Mean
# 2. Mode
# 3. Median
# 4. Drop those rows

# %%
data.head(20)
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories  DifferenceofPulse
# 0         60  01-12-2020    110       130     409.1                 20
# 1         60  02-12-2020    117       145     479.0                 28
# 2         60  03-12-2020    103       135     340.0                 32
# 3         45  04-12-2020    109       175     282.4                 66
# 4         45  05-12-2020    117       148     406.0                 31
# 5         60  06-12-2020    102       127     300.0                 25
# 6         60  07-12-2020    110       136     374.0                 26
# 7        450  08-12-2020    104       134     253.3                 30
# 8         30  09-12-2020    109       133     195.1                 24
# 9         60  10-12-2020     98       124     269.0                 26
# 10        60  11-12-2020    103       147     329.3                 44
# 11        60  12-12-2020    100       120     250.7                 20
# ...

# %%
data['Calories'] = data['Calories'].fillna(data['Calories'].mean())
print("Mean of Maxpulse:", data['Maxpulse'].mean())
print("Mode of Maxpulse:", data['Maxpulse'].mode())
print("Median of Maxpulse:", data['Maxpulse'].median())
# Out:
# Mean of Maxpulse: 128.5
# Mode of Maxpulse: 0    120
# Name: Maxpulse, dtype: int64
# Median of Maxpulse: 127.5

# %%
data.shape
# Out:
# (32, 6)

# %%
data.isnull().sum()
# Out:
# Duration             0
# Date                 1
# Pulse                0
# Maxpulse             0
# Calories             0
# DifferenceofPulse    0
# dtype: int64

# %%
data_cleaned = data.dropna()
data_cleaned.shape
# Out:
# (29, 5)

# %%
data_cleaned.shape
# Out:
# (31, 6)

# %% [markdown]
# Delete data in a particular row

# %%
data_2 = data.dropna(subset = ['Calories'])
print(data_2.isnull().sum())
print(data_2.shape)
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64
# (30, 5)
